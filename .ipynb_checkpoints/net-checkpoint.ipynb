# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pandas as pd
import seaborn as sns
import os
from graph_tool.all import *
import scipy as sp
import sklearn
from tqdm import tqdm

import imageio
import os
import shutil

# %%
edges = np.loadtxt("transitions_low_mut.txt").astype(int)
state_map  = np.loadtxt("state_map_low_mut.txt", dtype=str, delimiter=",")[1:-1]

# %%
edges_df = pd.DataFrame({"from":edges[:,0]-1,"to":edges[:,1]-1,"freq":edges[:,2]})

# %%
def compute_mean(list_s):
    digits = np.array([[int(char) for char in s] for s in list_s])
    return np.mean(digits)

def compute_sum(list_s):
    digits = np.array([[int(char) for char in s] for s in list_s])
    return np.sum(digits)

# %%
sm_keys = np.array([sm.split(":")[0][1:-1].split("+") for sm in state_map])
sm_vals = [sm.split(":")[1][:] for sm in state_map]
state_df = pd.DataFrame({"idx":np.array(sm_vals).astype(int)-1, "type":sm_keys[:,0], "mut":sm_keys[:,1]})
state_df["nchr"] = state_df["type"].map(lambda x: len(x.split("/")))
state_df["ngenes"] = state_df["type"].map(lambda x: compute_sum(x.split("/")))
state_df["meanmut"] = state_df["mut"].map(lambda x: compute_mean(x.split("/")))
state_df = state_df.sort_values("idx")
state_df = state_df.reset_index(drop=True)
state_df
# Out:
# /home/ubuntu/miniconda3/envs/compl/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/miniconda3/envs/compl/lib/python3.13/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#          idx                                               type  \
# 0          0  1111111111111111/1211111111111101/111111111111...
# 1          1                  1111111111111111/1111111111111111
# 2          2  1111111111111111/1111111111111111/111111111111...
# 3          3  1111111111111111/1111111111111111/111111111111...
# 4          4  1111111111111111/1111111111111111/111111111111...
# ...      ...                                                ...
# 19613  19615  1111111111011111/1111111111111111/111111111111...
# 19614  19616                  1111211111001111/1111121222211111
# 19615  19617                                              66666
# 19616  19618  1111111111111110/1111111111111111/111111111111...
# 19617  19619  1111111122222222/1111111111111111/111111112222...
#
#                                                      mut  nchr  ngenes  \
# 0      1001111101101101/1210111111111100/010111111010...     3    48.0
# 1                      0011111111101111/0110100011001100     2    32.0
# 2      0010011101110101/0100100011111110/010010001111...     3    48.0
# 3      1011111101110111/0101101111111000/010110111111...     3    48.0
# 4      0001111100101101/1100101111111110/110111110010...     3    48.0
# ...                                                  ...   ...     ...
# 19613  1111111111011110/1111111111111111/110111111111...     3    47.0
# 19614                  1011111110001111/0111101022001101     2    36.0
# 19615                                              11111     1    30.0
# 19616  1101111111111110/1110111111111110/111110101111...     3    47.0
# 19617  1101111122222220/1101111111111100/110111112222...     3    64.0
#
#         meanmut
# 0      0.770833
# 1      0.625000
# 2      0.562500
# 3      0.687500
# 4      0.666667
# ...         ...
# 19613  0.916667
# 19614  0.750000
# 19615  1.000000
# 19616  0.833333
# 19617  1.145833
#
# [19618 rows x 6 columns]

# %%
def get_state(idxs, df=state_df):
    if isinstance(idxs, int):
        return df[df['idx']==idxs]
    # Check if the input is a list
    elif isinstance(idxs, (list, np.ndarray)):
        return df[np.isin(df['idx'], idxs)]
    else:
        return "Input is neither a number nor a list."

# %%
ss0 = state_df[state_df["mut"] == "0000000000000000/0000000000000000"]
wt_state = ss0[ss0["type"] == "1111111111111111/1111111111111111"]['idx'].iloc[0]
dead_state = state_df[state_df["type"]=="66666"]['idx'].iloc[0]
ss0_pert = state_df[state_df["mut"] == "0000010000000000/0100000000000000"]
pert_state = ss0_pert[ss0_pert["type"] == "1111111111111111/1111111111111111"]['idx'].iloc[0]

# %%
edge_list = edges_df[["from","to"]].values

g = Graph(directed=True)
g.add_edge_list(edge_list)
g.ep['w'] = g.new_edge_property("int", vals=edges_df["freq"])

nchr = np.zeros(g.num_vertices())
for i in range(g.num_vertices()):
    if i in state_df['idx'].values:
        nchr[i]=state_df[state_df["idx"]==i]['nchr'].values[0]
g.vp['nchr'] = g.new_vertex_property("int", vals=nchr)

ng = np.zeros(g.num_vertices())
for i in range(g.num_vertices()):
    if i in state_df['idx'].values:
        ng[i]=state_df[state_df["idx"]==i]['ngenes'].values[0]
g.vp['ng'] = g.new_vertex_property("int", vals=ng)

avg_mut = np.zeros(g.num_vertices())
for i in range(g.num_vertices()):
    if i in state_df['idx'].values:
        avg_mut[i]=state_df[state_df["idx"]==i]['meanmut'].values[0]
g.vp['avgmut'] = g.new_vertex_property("float", vals=avg_mut)
#remove_self_loops(g)
g
# Out:
# <Graph object, directed, with 19620 vertices and 56107 edges, 3 internal vertex properties, 1 internal edge property, at 0x7fd34bcb9400>

# %%
in_deg = g.degree_property_map("in").a
out_deg = g.degree_property_map("out").a

vsize = g.new_vertex_property("float", vals=np.log(in_deg+1)*10)
#vsize = g.new_vertex_property("float", vals = np.exp(g.vp['ng'].a*0.05))
vsize.a[wt_state] = 25
vsize.a[dead_state] = 25
vsize.a[pert_state] = 15

v_color = g.new_vertex_property("vector<double>", vals=[cm.gray_r(s)[:3] for s in g.vp['avgmut'].a])
v_color[g.vertex(dead_state)] = [1,0,0]
#v_color[g.vertex(wt_state)] = [0,0,1]
v_color[g.vertex(pert_state)] = [0,0,1]

esize = g.new_edge_property("float", vals=np.log(g.ep['w'].a+1)*0.5)

# %%
pr = pagerank(g)
state_df['pr'] = state_df['idx'].map(lambda x: pr.a[x])

# %%
state_df_sort = state_df.copy()
state_df_sort.sort_values('pr')
# Out:
#          idx                                               type  \
# 16979  16981                  1111111111100011/1111111111111111
# 14531  14533                  1111111111111110/1111111111111111
# 16746  16748                  1111111111111100/1111111111111111
# 14711  14713                  1111111111111111/1111111111111111
# 17765  17767                  1111111111111111/1111111111111100
# ...      ...                                                ...
# 10816  10818  1111111111111111/1111111100001111/111111111111...
# 8575    8577  1111111111111111/1111111111111111/111111111111...
# 17928  17930                  1111111111111111/1111111001111111
# 17971  17973                  1111111111111112/1111111111111111
# 19615  19617                                              66666
#
#                                                      mut  nchr  ngenes  \
# 16979                  1110111111100010/0111111111111101     2    29.0
# 14531                  1110111111111110/0111111111111101     2    31.0
# 16746                  1110111111111100/0111111111111101     2    30.0
# 14711                  1110111111111111/0111111111111101     2    32.0
# 17765                  1110111111111110/0111111111111100     2    30.0
# ...                                                  ...   ...     ...
# 10816  1111011111111100/1111101100001111/111101111111...     4    63.0
# 8575   1111111111111110/0111111111111101/111111111111...     4    64.0
# 17928                  1111111111111101/1111111001111110     2    30.0
# 17971                  1111111111111112/0101111111111100     2    33.0
# 19615                                              11111     1    30.0
#
#         meanmut        pr
# 16979  0.781250  0.000020
# 14531  0.875000  0.000020
# 16746  0.843750  0.000020
# 14711  0.906250  0.000020
# 17765  0.843750  0.000020
# ...         ...       ...
# 10816  0.843750  0.000189
# 8575   0.921875  0.000191
# 17928  0.875000  0.000192
# 17971  0.906250  0.000193
# 19615  1.000000  0.283147
#
# [19618 rows x 7 columns]

# %%
#pos = sfdp_layout(g)
pos = random_layout(g)
#pos = arf_layout(g)
#pos = radial_tree_layout(g, root=g.vertex(wt_state))
#pos = fruchterman_reingold_layout(g, r=2)

# %%
graph_draw(g, pos=pos, 
           vertex_size=vsize, 
           vertex_fill_color=v_color, vertex_color="k",# vertex_text="ciao",# vertex_font_size=10,
           edge_pen_width=esize, edge_marker_size=7, 
           bg_color="w")#, output="images/graph_example.png")
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7fd34bcb9400, at 0x7fd34d5efc20>

# %%
plt.subplots(1,2,figsize=(12,5))
plt.subplot(1,2,1)
plt.hist(state_df["ngenes"], bins=50)
plt.title("N genes", fontweight="bold")
plt.subplot(1,2,2)
plt.hist(state_df["nchr"])
plt.title("N chromosomes", fontweight="bold")
plt.tight_layout()

# %%
def get_second_order_neighbors(g, v, which="all"):
    neighs=[]
    if which=="all":
        first_order = g.get_all_neighbors(v)
        for ai in first_order:
            neighs.append(g.get_all_neighbors(g.vertex(ai)))
    if which=="in":
        first_order = g.get_in_neighbors(v)
        for ai in first_order:
            neighs.append(g.get_in_neighbors(g.vertex(ai)))
    if which=="out":
        first_order = g.get_out_neighbors(v)
        for ai in first_order:
            neighs.append(g.get_out_neighbors(g.vertex(ai)))
    
    return np.unique(np.concatenate(neighs))

# %%
def subset_graph(g, v_list):
    graph_map = np.isin(np.arange(g.num_vertices()), v_list)
    g_view = GraphView(g, graph_map)
    g_sub = Graph(g_view, prune=True)
    return g_sub

# %%
pert_state
# Out:
# np.int64(3494)

# %%
v_list = get_second_order_neighbors(g, g.vertex(397), which="out")
g_sub = subset_graph(g, v_list)

# %%
graph_draw(g_sub)
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7fd34c0e96d0, at 0x7fd34be71a20>

# %%
ppp = shortest_path(g, g.vertex(pert_state), g.vertex(dead_state))

# %%
ppp
# Out:
# ([<Vertex object with index '3494' at 0x7fd34be83740>,
#   <Vertex object with index '19617' at 0x7fd34d4bb5c0>],
#  [<Edge object with source '3494' and target '19617' at 0x7fd34be85510>])

# %%
for p in ppp:
    print(p)
# Out:
# [<Vertex object with index '3494' at 0x7fd34be83740>, <Vertex object with index '19617' at 0x7fd34d4bb5c0>]
# [<Edge object with source '3494' and target '19617' at 0x7fd34be85510>]

# %%
state_df[np.isin(state_df['idx'],p)]
# Out:
# Empty DataFrame
# Columns: [idx, type, mut, nchr, ngenes, meanmut, pr]
# Index: []

# %%
get_second_order_neighbors(g, g.vertex(pert_state))
# Out:
# array([    0,     1,     2, ..., 19615, 19616, 19617], shape=(18820,))

# %%
neighs=[]
a = g.get_all_neighbors(g.vertex(pert_state))
for ai in a:
    neighs.append(g.get_all_neighbors(g.vertex(ai)))

# %%
neighs
# Out:
# [array([14366, 19617, 14366,  3494]),
#  array([19617,  3494]),
#  array([19617,  6490,  3494,  6490]),
#  array([19617,  3494]),
#  array([    2,     3,     4, ..., 13546, 19616, 11815], shape=(18819,)),
#  array([19617, 14579,  3494, 14579]),
#  array([ 6733, 19617,  6733,  3494]),
#  array([19617,  3445, 14004,  3445,  3494]),
#  array([19617,  1979,  2602,  1979,  3494]),
#  array([14366, 18642,  6490,  7680, 19617, 14579,  6733,  3445,  1979,
#          3494,  7420, 14967,  6368,  3504, 16005,  3494]),
#  array([ 6418,  7420, 19617,  8254, 14408, 10072,  7420,  3494]),
#  array([14967, 19617, 14967,  3494]),
#  array([18770,  3079,  5499,  9376,  6024, 15033, 19617,  6368, 13248,
#          9818,   887,  3494,  6368]),
#  array([ 5747, 19617,  3504,  3494,  3504]),
#  array([16005, 19617, 16005,  3494]),
#  array([14366, 18642,  6490,  7680, 19617, 14579,  6733,  3445,  1979,
#          3494,  7420, 14967,  6368,  3504, 16005,  3494])]

# %%
np.isin(np.arange(g.num_vertices()), g.get_all_neighbors(g.vertex(pert_state)))
# Out:
# array([False, False, False, ...,  True, False, False], shape=(19620,))

# %%
GraphView(g, vfilt=np.isin(np.arange(g.num_vertices()), g.get_all_neighbors(g.vertex(pert_state))))
# Out:
# <GraphView object, directed, with 15 vertices and 39 edges, 3 internal vertex properties, 1 internal edge property, edges filtered by <EdgePropertyMap object with value type 'bool', for Graph 0x7fd34bec96d0, at 0x7fd34be72c10>, vertices filtered by <VertexPropertyMap object with value type 'bool', for Graph 0x7fd34bec96d0, at 0x7fd34be72b30>, at 0x7fd34bec96d0>

# %%
g.get_all_neighbors(g.vertex(pert_state))
# Out:
# array([14366, 18642,  6490,  7680, 19617, 14579,  6733,  3445,  1979,
#         3494,  7420, 14967,  6368,  3504, 16005,  3494])

# %%
self_loops = np.zeros(g.num_vertices())
for i in range(g.num_vertices()):
    try:
        self_loops[i] = g.ep['w'][i,i]
    except:
        None

# %%
np.argsort(self_loops)[-1]
# Out:
# np.int64(5137)

# %%
get_state(g.get_all_neighbors(g.vertex(pert_state)))
# Out:
#          idx                               type  \
# 1978    1979  1111111111111111/1111111111111111
# 3443    3445  1111111111111111/1111111111111111
# 3492    3494  1111111111111111/1111111111111111
# 3502    3504  1111111111111111/1111111111111111
# 6366    6368  1111111111111111/1111111111111111
# 6488    6490  1111111111111111/1111111111111111
# 6731    6733  1111111111111111/1111111111111111
# 7418    7420  1111111111111111/1111111111111111
# 7678    7680  1111111111111111/1111111111111111
# 14364  14366  1111111111111111/1111111111111111
# 14577  14579  1111111111111111/1111111111111111
# 14965  14967  1111111111111111/1111111111111111
# 16003  16005  1111111111111111/1111111111111111
# 18640  18642  1111111111111111/1111111111111111
# 19615  19617                              66666
#
#                                      mut  nchr  ngenes  meanmut        pr
# 1978   0000010000000000/0100000000010000     2    32.0  0.09375  0.000029
# 3443   0001010000000000/0100000000000000     2    32.0  0.09375  0.000029
# 3492   0000010000000000/0100000000000000     2    32.0  0.06250  0.000021
# 3502   0000010000000000/0100000000100000     2    32.0  0.09375  0.000029
# 6366   0000010000000000/0100100000000000     2    32.0  0.09375  0.000023
# 6488   0000010000000000/0100000000001000     2    32.0  0.09375  0.000037
# 6731   0000110000000000/0100000000000000     2    32.0  0.09375  0.000037
# 7418   0000010100000000/0100000000000000     2    32.0  0.09375  0.000025
# 7678   0000010000000000/0100000100000000     2    32.0  0.09375  0.000021
# 14364  0000010001000000/0100000000000000     2    32.0  0.09375  0.000037
# 14577  0000010000000000/0101000000000000     2    32.0  0.09375  0.000037
# 14965  0000010000100000/0100000000000000     2    32.0  0.09375  0.000037
# 16003  1000010000000000/0100000000000000     2    32.0  0.09375  0.000037
# 18640  0010010000000000/0100000000000000     2    32.0  0.09375  0.000021
# 19615                              11111     1    30.0  1.00000  0.283147

# %%
state = minimize_blockmodel_dl(g)

# %%
state
# Out:
# <BlockState object with 19620 blocks (51 nonempty), degree-corrected, for graph <Graph object, directed, with 19620 vertices and 56107 edges, 3 internal vertex properties, 1 internal edge property, at 0x7fd34bcb9400>, at 0x7fd34bcf5be0>

# %%
state.draw()
